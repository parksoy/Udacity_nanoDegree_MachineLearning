# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'term', 'of', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  #tf.global_variables_initializer().run()
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.107607
# Nearest to they: fluffy, mysia, vincennes, headache, installments, sole, protozoa, antisemitism,
# Nearest to to: boh, emerging, devise, heritable, deregulation, atkinson, tiers, coretta,
# Nearest to if: initials, expositions, candidate, isdb, disambiguation, lain, aleph, unmodified,
# Nearest to their: castile, weiss, airspace, predicting, evagrius, lucca, lagrangian, radek,
# Nearest to for: matisse, tlatoani, slightly, sustainable, overwritten, chocolate, potato, defamation,
# Nearest to a: koh, gendered, remastered, bestselling, liturgies, cooke, ballets, abelian,
# Nearest to american: roskilde, planners, collector, wikibooks, desilu, seagram, winding, concern,
# Nearest to six: structuralism, paget, polemical, kumquats, patricio, relinquish, uncodified, computation,
# Nearest to over: gbit, mh, rockin, nihilist, concentrated, conductor, arukh, dungeon,
# Nearest to five: boo, sebastian, environment, conceit, heterodox, rees, alford, emery,
# Nearest to have: hani, heidelberg, dsn, margraves, ally, pitching, cereal, periphery,
# Nearest to would: rebelling, rotary, veritas, merz, pogues, append, standout, cooking,
# Nearest to by: papias, walkway, extrasolar, mallory, djbdns, sorting, duodenum, clarity,
# Nearest to are: tricks, stairway, floated, zoos, stead, robbie, overman, originally,
# Nearest to s: disrupts, privacy, espagnole, trinity, cma, pics, courtship, galactic,
# Nearest to years: pit, consulship, sprawling, peng, sobriety, europa, ibid, lettre,
# Average loss at step 2000: 4.358567
# Average loss at step 4000: 3.864103
# Average loss at step 6000: 3.786897
# Average loss at step 8000: 3.691354
# Average loss at step 10000: 3.612682
# Nearest to they: he, she, we, not, it, who, there, lick,
# Nearest to to: suharto, peep, cannot, into, pathways, will, alchemist, would,
# Nearest to if: initials, passy, isdb, disambiguation, quebec, conflicts, scat, original,
# Nearest to their: his, its, fife, some, forbidding, her, elections, quarto,
# Nearest to for: defamation, of, ariadne, after, in, with, menai, peritoneum,
# Nearest to a: the, turmeric, this, archimandrite, any, remastered, dat, items,
# Nearest to american: erwin, planners, boomers, effigy, trickster, distressed, gareth, guilt,
# Nearest to six: eight, seven, five, three, nine, four, zero, two,
# Nearest to over: rockin, concentrated, blackjack, gbit, mh, officially, lionel, ml,
# Nearest to five: six, eight, seven, three, nine, four, zero, two,
# Nearest to have: had, be, has, doctrinal, are, ability, hrothgar, bukovina,
# Nearest to would: can, will, could, may, beginner, should, cobain, might,
# Nearest to by: was, be, from, mallory, during, sheldon, on, into,
# Nearest to are: were, is, was, have, multiprogramming, menai, discos, be,
# Nearest to s: his, hetfield, the, mariani, and, buckinghamshire, exercises, shui,
# Nearest to years: consulship, sobriety, punks, europa, ibid, lettre, commissioning, auric,
# Average loss at step 12000: 3.599933
# Average loss at step 14000: 3.569580
# Average loss at step 16000: 3.411540
# Average loss at step 18000: 3.458097
# Average loss at step 20000: 3.534464
# Nearest to they: he, there, we, she, it, you, who, not,
# Nearest to to: will, can, would, not, alchemist, could, suharto, cannot,
# Nearest to if: when, though, because, passy, might, khoikhoi, initials, cannot,
# Nearest to their: his, its, the, her, some, any, heritable, forbidding,
# Nearest to for: of, in, with, defamation, by, improving, after, barely,
# Nearest to a: archimandrite, any, turmeric, the, this, gear, dat, items,
# Nearest to american: and, erwin, british, boomers, russian, monists, guilt, interim,
# Nearest to six: eight, five, seven, nine, four, three, two, zero,
# Nearest to over: rockin, remediation, lexington, glissando, lionel, preprocessor, smarter, concentrated,
# Nearest to five: six, seven, eight, four, three, two, zero, nine,
# Nearest to have: had, has, be, were, are, bukovina, swallow, take,
# Nearest to would: can, could, will, may, should, might, to, cobain,
# Nearest to by: be, through, in, into, were, evi, mallory, from,
# Nearest to are: were, is, have, was, frequentist, amphitheatre, be, orie,
# Nearest to s: dagestan, rutles, planina, admittedly, isbn, mau, sa, aru,
# Nearest to years: consulship, qutb, sobriety, farmers, yaum, psychoacoustics, telephus, auric,
# Average loss at step 22000: 3.507283
# Average loss at step 24000: 3.489418
# Average loss at step 26000: 3.475116
# Average loss at step 28000: 3.475573
# Average loss at step 30000: 3.505624
# Nearest to they: there, he, we, it, you, she, who, these,
# Nearest to to: would, cannot, will, can, could, atkinson, suharto, bullpen,
# Nearest to if: when, though, might, cannot, because, considers, can, passy,
# Nearest to their: his, its, her, the, some, cautious, fianna, our,
# Nearest to for: with, ariadne, defamation, when, by, after, of, hoarding,
# Nearest to a: the, vauban, any, turmeric, anguish, no, maranh, competition,
# Nearest to american: british, erwin, russian, canadian, french, aryan, interim, australian,
# Nearest to six: eight, nine, four, seven, five, three, zero, two,
# Nearest to over: rockin, glissando, nearly, liliales, preprocessor, connolly, operands, along,
# Nearest to five: four, eight, seven, six, three, nine, zero, two,
# Nearest to have: had, has, were, are, be, include, swallow, having,
# Nearest to would: could, can, will, may, should, might, must, to,
# Nearest to by: from, in, was, for, were, after, parker, under,
# Nearest to are: were, is, have, those, these, obscurity, be, other,
# Nearest to s: his, dagestan, christiansen, isbn, gamba, install, cdp, mau,
# Nearest to years: consulship, sobriety, qutb, months, year, days, farmers, rogue,
# Average loss at step 32000: 3.500368
# Average loss at step 34000: 3.492510
# Average loss at step 36000: 3.455486
# Average loss at step 38000: 3.298547
# Average loss at step 40000: 3.426805
# Nearest to they: we, he, you, there, she, it, who, these,
# Nearest to to: will, suharto, could, submersible, and, ibiza, in, cannot,
# Nearest to if: when, though, might, khoikhoi, could, can, cohorts, is,
# Nearest to their: its, his, her, the, some, cautious, fianna, any,
# Nearest to for: in, by, of, defamation, unlike, seas, busting, nad,
# Nearest to a: the, archimandrite, clays, any, turmeric, pun, draconian, specialties,
# Nearest to american: british, french, canadian, russian, german, jes, cannibalistic, scottish,
# Nearest to six: four, eight, seven, five, nine, three, two, one,
# Nearest to over: nearly, glissando, agnesi, rockin, lcd, preprocessor, semite, cryptanalyst,
# Nearest to five: seven, six, four, three, eight, nine, two, zero,
# Nearest to have: had, has, were, be, are, include, find, bukovina,
# Nearest to would: could, will, can, may, might, should, must, did,
# Nearest to by: from, for, through, be, with, mallory, compactification, extrasolar,
# Nearest to are: were, have, is, be, include, those, including, these,
# Nearest to s: his, christiansen, buckinghamshire, dagestan, ganesh, diaphragm, her, itosu,
# Nearest to years: days, months, consulship, sobriety, qutb, year, punks, rogue,
# Average loss at step 42000: 3.432288
# Average loss at step 44000: 3.453286
# Average loss at step 46000: 3.448642
# Average loss at step 48000: 3.357007
# Average loss at step 50000: 3.380401
# Nearest to they: we, he, there, you, she, it, who, not,
# Nearest to to: suharto, devise, would, may, cannot, can, plateau, ibiza,
# Nearest to if: when, before, though, could, where, although, might, can,
# Nearest to their: its, his, her, cautious, the, both, some, donations,
# Nearest to for: ariadne, against, through, with, after, defamation, during, menai,
# Nearest to a: foundered, the, any, turmeric, items, merlot, fortuna, no,
# Nearest to american: french, british, russian, canadian, scottish, cannibalistic, jes, indian,
# Nearest to six: eight, seven, four, five, three, nine, two, zero,
# Nearest to over: through, semite, nearly, glissando, dualist, preprocessor, agnesi, lcd,
# Nearest to five: four, six, seven, eight, three, nine, two, zero,
# Nearest to have: had, has, were, be, are, include, having, bukovina,
# Nearest to would: could, will, can, may, might, should, must, cannot,
# Nearest to by: through, with, was, during, from, nicolau, under, mallory,
# Nearest to are: were, is, have, those, although, be, topping, these,
# Nearest to s: christiansen, and, his, wigs, itosu, whose, dagestan, tomahawk,
# Nearest to years: days, months, times, year, consulship, rogue, sobriety, qutb,
# Average loss at step 52000: 3.438439
# Average loss at step 54000: 3.428798
# Average loss at step 56000: 3.435566
# Average loss at step 58000: 3.394611
# Average loss at step 60000: 3.389853
# Nearest to they: we, there, you, he, she, it, these, would,
# Nearest to to: devise, would, will, not, touching, for, peep, hasten,
# Nearest to if: when, where, though, before, although, then, could, so,
# Nearest to their: its, his, her, the, cautious, our, your, whose,
# Nearest to for: of, without, after, defamation, when, ignition, to, regarding,
# Nearest to a: the, another, any, turmeric, galois, every, openings, prototypical,
# Nearest to american: british, german, scottish, indian, french, analysis, ionospheric, russian,
# Nearest to six: eight, four, five, seven, nine, three, two, zero,
# Nearest to over: through, nearly, along, dualist, preprocessor, agnesi, between, semite,
# Nearest to five: four, six, three, eight, seven, nine, two, zero,
# Nearest to have: has, had, include, were, are, be, having, yet,
# Nearest to would: could, will, can, may, might, should, must, did,
# Nearest to by: through, without, emulsion, evi, parker, extrasolar, from, incursion,
# Nearest to are: were, is, have, including, those, these, be, topping,
# Nearest to s: dagestan, christiansen, whose, entente, symmes, mau, aru, warlike,
# Nearest to years: days, months, times, year, qutb, centuries, sobriety, consulship,
# Average loss at step 62000: 3.234974
# Average loss at step 64000: 3.255524
# Average loss at step 66000: 3.404473
# Average loss at step 68000: 3.386643
# Average loss at step 70000: 3.356709
# Nearest to they: we, he, there, you, she, it, these, then,
# Nearest to to: must, will, would, cannot, could, can, devise, peep,
# Nearest to if: when, though, although, before, where, however, after, could,
# Nearest to their: its, his, her, the, our, cautious, your, any,
# Nearest to for: defamation, without, regarding, in, directx, against, menai, to,
# Nearest to a: archimandrite, the, another, any, enough, penn, draconian, pont,
# Nearest to american: british, canadian, dixie, german, truetype, french, russian, arab,
# Nearest to six: eight, four, seven, nine, five, three, two, zero,
# Nearest to over: nearly, through, dualist, around, full, rockin, preprocessor, phonation,
# Nearest to five: four, six, eight, nine, seven, three, two, zero,
# Nearest to have: had, has, were, are, include, be, having, paddles,
# Nearest to would: will, could, might, may, can, should, must, cannot,
# Nearest to by: through, evi, from, duodenum, extrasolar, fim, masse, be,
# Nearest to are: were, have, including, is, these, include, although, those,
# Nearest to s: christiansen, reptilian, agave, confessional, planina, must, whose, ja,
# Nearest to years: days, months, times, year, decades, qutb, centuries, minutes,
# Average loss at step 72000: 3.374362
# Average loss at step 74000: 3.342793
# Average loss at step 76000: 3.309674
# Average loss at step 78000: 3.350974
# Average loss at step 80000: 3.378342
# Nearest to they: we, he, there, you, she, it, these, soon,
# Nearest to to: suharto, devise, would, can, eschewing, rink, harpercollins, lucifer,
# Nearest to if: when, though, although, before, where, then, could, so,
# Nearest to their: its, his, her, our, your, cautious, the, these,
# Nearest to for: ariadne, rightful, charenton, obstetrics, without, defamation, citations, octavio,
# Nearest to a: the, archimandrite, kzinti, clays, spiegel, another, sized, enough,
# Nearest to american: british, canadian, scottish, french, irish, russian, aryan, german,
# Nearest to six: eight, seven, five, four, three, nine, two, one,
# Nearest to over: nearly, around, through, phonation, agnesi, lamm, authorised, across,
# Nearest to five: six, seven, four, eight, three, nine, zero, two,
# Nearest to have: had, has, include, be, were, are, having, contain,
# Nearest to would: could, will, might, may, can, must, should, cannot,
# Nearest to by: through, interned, from, extrasolar, duodenum, mallory, svg, projekt,
# Nearest to are: were, have, include, those, is, including, these, contain,
# Nearest to s: salvador, mau, whose, isbn, greyhounds, dagestan, cdp, sentries,
# Nearest to years: days, months, year, times, minutes, decades, centuries, weeks,
# Average loss at step 82000: 3.408331
# Average loss at step 84000: 3.406886
# Average loss at step 86000: 3.383755
# Average loss at step 88000: 3.348500
# Average loss at step 90000: 3.361546
# Nearest to they: we, he, she, there, you, it, soon, these,
# Nearest to to: suharto, devise, will, would, airframes, could, rarities, cannot,
# Nearest to if: when, though, where, so, although, since, after, before,
# Nearest to their: its, his, her, our, your, cautious, my, the,
# Nearest to for: ariadne, including, of, defamation, after, without, during, pinnacles,
# Nearest to a: any, the, another, galois, obstructing, archimandrite, scout, kzinti,
# Nearest to american: british, french, canadian, scottish, german, irish, indian, jes,
# Nearest to six: eight, seven, four, nine, five, three, two, zero,
# Nearest to over: nearly, through, around, off, lamm, rockin, agnesi, within,
# Nearest to five: eight, seven, four, three, six, nine, two, zero,
# Nearest to have: had, has, were, include, are, be, provide, having,
# Nearest to would: could, will, might, may, can, should, must, cannot,
# Nearest to by: through, extrasolar, without, from, mallory, while, with, lemonade,
# Nearest to are: were, is, include, these, have, those, electrically, contain,
# Nearest to s: his, whose, mau, christiansen, own, hateful, antipathy, isbn,
# Nearest to years: days, months, decades, year, minutes, centuries, times, weeks,
# Average loss at step 92000: 3.398775
# Average loss at step 94000: 3.254046
# Average loss at step 96000: 3.358592
# Average loss at step 98000: 3.241226
# Average loss at step 100000: 3.350495
# Nearest to they: we, he, you, there, she, it, i, soon,
# Nearest to to: will, could, would, must, devise, cannot, can, suharto,
# Nearest to if: when, though, where, while, so, before, although, follows,
# Nearest to their: its, his, her, our, your, cautious, the, whose,
# Nearest to for: when, although, including, without, after, if, tamer, rigorous,
# Nearest to a: any, the, another, fitz, enough, formalized, draconian, eskimos,
# Nearest to american: british, canadian, french, scottish, irish, russian, italian, australian,
# Nearest to six: seven, eight, four, five, nine, three, two, zero,
# Nearest to over: nearly, around, through, rockin, wedge, phonation, lamm, off,
# Nearest to five: seven, four, six, eight, three, nine, two, zero,
# Nearest to have: had, has, were, include, provide, having, are, be,
# Nearest to would: could, will, might, may, can, should, must, cannot,
# Nearest to by: through, projekt, from, extrasolar, initially, without, under, mallory,
# Nearest to are: were, those, include, these, have, is, electrically, while,
# Nearest to s: his, whose, christiansen, tyrone, my, drunkenness, isbn, ja,
# Nearest to years: days, months, decades, year, times, centuries, minutes, weeks,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
