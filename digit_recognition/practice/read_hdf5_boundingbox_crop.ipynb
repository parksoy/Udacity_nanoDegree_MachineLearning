# %%
import numpy as np
import h5py

# %%
f=h5py.File('./test/digitStruct.mat', 'r')
for name in f:
    print name
# Out:
# #refs#
# digitStruct

# %%
#keys(), values(), items() and iter(), get()

# %%
for name in f['digitStruct']:
    print name
# Out:
# bbox
# name

# %%
print f['digitStruct']['bbox']
print f['digitStruct']['name']
print f['digitStruct']['bbox'].value
print f['digitStruct']['bbox'].item()
#attr = [self.inf[attr.value[j].item()].value[0][0] for j in range(len(attr))]
# Out:
# <HDF5 dataset "bbox": shape (13068, 1), type "|O">
# <HDF5 dataset "name": shape (13068, 1), type "|O">
# [[<HDF5 object reference>]
#  [<HDF5 object reference>]
#  [<HDF5 object reference>]
#  ...,
#  [<HDF5 object reference>]
#  [<HDF5 object reference>]
#  [<HDF5 object reference>]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-358109f7eaed> in <module>()
#       2 print f['digitStruct']['name']
#       3 print f['digitStruct']['bbox'].value
# ----> 4 print f['digitStruct']['bbox'].item()
#       5 #attr = [self.inf[attr.value[j].item()].value[0][0] for j in range(len(attr))]
#
# AttributeError: 'Dataset' object has no attribute 'item'

# %%
for name in f['digitStruct']['bbox']:
    print name
# Out:
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# [<HDF5 object reference>]
# ...

# %%
bb = self.digitStructBbox[n].item()
bbox['height'] = self.bboxHelper(self.inf[bb]["height"])

# %%
[chr(c[0]) for c in self.inf[self.digitStructName[n][0]].value]
